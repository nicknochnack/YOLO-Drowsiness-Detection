# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...
#      ---------------------------------------- 0.0/3.1 GB ? eta -:--:--
#      ---------------------------------------- 0.0/3.1 GB 4.8 MB/s eta 0:10:38
#      ---------------------------------------- 0.0/3.1 GB 4.9 MB/s eta 0:10:24
#      ---------------------------------------- 0.0/3.1 GB 5.4 MB/s eta 0:09:21
#      ---------------------------------------- 0.0/3.1 GB 5.7 MB/s eta 0:09:00
#      ---------------------------------------- 0.0/3.1 GB 5.1 MB/s eta 0:09:54
#      ---------------------------------------- 0.0/3.1 GB 4.4 MB/s eta 0:11:36
#      ---------------------------------------- 0.0/3.1 GB 3.9 MB/s eta 0:13:12
#      ---------------------------------------- 0.0/3.1 GB 3.8 MB/s eta 0:13:22
#      ---------------------------------------- 0.0/3.1 GB 3.1 MB/s eta 0:16:39
#      ---------------------------------------- 0.0/3.1 GB 3.3 MB/s eta 0:15:33
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/184.3 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/184.3 kB ? eta -:--:--
#      -------- ---------------------------- 41.0/184.3 kB 495.5 kB/s eta 0:00:01
#      --------------------- -------------- 112.6/184.3 kB 939.4 kB/s eta 0:00:01
#      ----------------------------------- -- 174.1/184.3 kB 1.2 MB/s eta 0:00:01
#      ----------------------------------- -- 174.1/184.3 kB 1.2 MB/s eta 0:00:01
#      ----------------------------------- -- 174.1/184.3 kB 1.2 MB/s eta 0:00:01
#      ------------------------------------ 184.3/184.3 kB 657.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      - -------------------------------------- 0.2/7.6 MB 6.3 MB/s eta 0:00:02
#      - -------------------------------------- 0.3/7.6 MB 3.8 MB/s eta 0:00:02
#      -- ------------------------------------- 0.5/7.6 MB 4.2 MB/s eta 0:00:02
# ...

# %%
# !pip3 install ipywidgets
# Out:
# ...
#   Using cached ipywidgets-8.0.6-py3-none-any.whl (138 kB)
# ...
#   Using cached jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
# ...
#   Using cached widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\atulv/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-4-8 Python-3.9.13 torch-1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# # 3. Make Detections with Images

# %%
img = 'https://www.vbetnews.com/uploads/2022/01/2961525-60786428-2560-1440-1024x576.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 576x1024 2 persons
# Speed: 1994.0ms pre-process, 193.2ms inference, 8.6ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[ 74,  74,  74],
#          [ 77,  77,  77],
#          [ 77,  77,  77],
#          ...,
#          [ 78,  78,  78],
#          [ 78,  78,  78],
#          [ 79,  79,  79]],
#
#         [[ 74,  74,  74],
#          [ 77,  77,  77],
#          [ 77,  77,  77],
#          ...,
#          [ 81,  81,  81],
#          [ 81,  81,  81],
#          [ 81,  81,  81]],
#
#         [[ 73,  73,  73],
#          [ 76,  76,  76],
#          [ 77,  77,  77],
#          ...,
#          [ 83,  83,  83],
#          [ 83,  83,  83],
#          [ 83,  83,  83]],
#
#         ...,
#
#         [[ 88,  77,  85],
#          [ 88,  77,  85],
#          [ 88,  78,  86],
#          ...,
#          [124, 139, 144],
#          [123, 138, 143],
#          [123, 138, 143]],
#
#         [[ 86,  76,  84],
#          [ 86,  76,  84],
#          [ 87,  77,  85],
#          ...,
#          [123, 138, 143],
#          [124, 139, 144],
#          [125, 140, 145]],
#
#         [[ 85,  75,  83],
# ...

# %% [markdown]
# # 4. Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 6
#       3 ret, frame = cap.read()
#       5 # Make detections
# ----> 6 results = model(frame)
#       8 cv2.imshow('YOLO', np.squeeze(results.render()))
#      10 if cv2.waitKey(10) & 0xFF == ord('q'):
#
# File D:\Atul\3_Code_Samples\YoloV5_model\YOLO-Drowsiness-Detection\venv\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# ...

# %% [markdown]
# # 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['payingAttention', 'notPayingAttention']
number_imgs = 5

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\payingAttention.cf71bb20-d638-11ed-82e6-4cd577791cae.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\payingAttention.d564bff8-d638-11ed-b481-4cd577791cae.jpg
# ...
# data\images\payingAttention.d564bff9-d638-11ed-940e-4cd577791cae.jpg
# ...
# data\images\payingAttention.d564bffa-d638-11ed-8459-4cd577791cae.jpg
# ...
# data\images\payingAttention.d564bffb-d638-11ed-8ee5-4cd577791cae.jpg
# ...
# data\images\payingAttention.d564bffc-d638-11ed-abfa-4cd577791cae.jpg
# ...
# data\images\notPayingAttention.d564bffd-d638-11ed-8f5a-4cd577791cae.jpg
# ...
# data\images\notPayingAttention.d564bffe-d638-11ed-bbdc-4cd577791cae.jpg
# ...
# data\images\notPayingAttention.d564bfff-d638-11ed-bc68-4cd577791cae.jpg
# ...
# data\images\notPayingAttention.d564c000-d638-11ed-8218-4cd577791cae.jpg
# ...
# data\images\notPayingAttention.d564c001-d638-11ed-82ce-4cd577791cae.jpg

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
#      ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.8 MB 1.3 MB/s eta 0:00:06
#      ---------------------------------------- 0.0/6.8 MB 393.8 kB/s eta 0:00:18
#       --------------------------------------- 0.1/6.8 MB 819.2 kB/s eta 0:00:09
#       --------------------------------------- 0.1/6.8 MB 798.9 kB/s eta 0:00:09
#      - -------------------------------------- 0.2/6.8 MB 981.9 kB/s eta 0:00:07
#      - -------------------------------------- 0.3/6.8 MB 1.2 MB/s eta 0:00:06
#      --- ------------------------------------ 0.5/6.8 MB 1.7 MB/s eta 0:00:04
#      --- ------------------------------------ 0.6/6.8 MB 1.7 MB/s eta 0:00:04
#      ----- ---------------------------------- 0.9/6.8 MB 2.3 MB/s eta 0:00:03
#      ------ --------------------------------- 1.1/6.8 MB 2.6 MB/s eta 0:00:03
#      ------ --------------------------------- 1.1/6.8 MB 2.3 MB/s eta 0:00:03
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# ^C

# %% [markdown]
# # 6. Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp7/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\atulv/.cache\torch\hub\master.zip
# YOLOv5  2023-4-9 Python-3.9.13 torch-1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'notPayingAttention.5cc11b36-d55a-11ed-9651-3c91808863fe')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 16.0ms pre-process, 11.0ms inference, 2.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
